# %% [markdown]
# <a href="https://colab.research.google.com/github/GunduSriBhanu/data690_fall2022/blob/main/assignment_06/assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 06
# ### Note:
# - For visualization, you should use Plotly Express
# - Use this notebook as your template and follow the instructions
#
# The first half of this assignment is similar to assignment 04.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# The links to the zip file is:
#
# - https://collegescorecard.ed.gov/data (This web page contains the link to the zip file)
#
# - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip (The link to the zip file)
#
# You can run `!wget` command in Colab notebook to retrieve it directly, then run `!unzip` command to extract files (I have provided the cells to do so next for your convenience)
#
# Your folder structure should look like this in your Colab enviroment:
#
# - ...
# - 'MERGED1996_97_PP.csv',
# - 'MERGED2015_16_PP.csv',
# - ...
# - 'MERGED2017_18_PP.csv'
# - ...
#
# **Note: you should refresh the folder to see all files.**

# %% [markdown]
# ## Step 1 - Retrieve the zip file

# %%
# !wget https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip
# Out:
# --2022-10-08 20:45:10--  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09012022.zip
# Resolving ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)... 160.1.161.208, 3.30.138.208, 2600:1f12:18a:7d00:b09b:4280:b7b0:6085, ...
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|160.1.161.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 410294884 (391M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data_09012022.zip’
#
# CollegeScorecard_Ra 100%[===================>] 391.29M  33.8MB/s    in 13s
#
# 2022-10-08 20:45:23 (29.7 MB/s) - ‘CollegeScorecard_Raw_Data_09012022.zip’ saved [410294884/410294884]

# %% [markdown]
# ## Step 2 - Unzip the zip file

# %%
# !unzip CollegeScorecard_Raw_Data_09012022.zip
# Out:
# Archive:  CollegeScorecard_Raw_Data_09012022.zip
#  extracting: Crosswalks.zip
#   inflating: data.yaml
#   inflating: FieldOfStudyData1415_1516_PP.csv
#   inflating: FieldOfStudyData1516_1617_PP.csv
#   inflating: FieldOfStudyData1617_1718_PP.csv
#   inflating: FieldOfStudyData1718_1819_PP.csv
#   inflating: MERGED1996_97_PP.csv
#   inflating: MERGED1997_98_PP.csv
#   inflating: MERGED1998_99_PP.csv
#   inflating: MERGED1999_00_PP.csv
#   inflating: MERGED2000_01_PP.csv
#   inflating: MERGED2001_02_PP.csv
#   inflating: MERGED2002_03_PP.csv
#   inflating: MERGED2003_04_PP.csv
#   inflating: MERGED2004_05_PP.csv
#   inflating: MERGED2005_06_PP.csv
#   inflating: MERGED2006_07_PP.csv
#   inflating: MERGED2007_08_PP.csv
#   inflating: MERGED2008_09_PP.csv
#   inflating: MERGED2009_10_PP.csv
#   inflating: MERGED2010_11_PP.csv
#   inflating: MERGED2011_12_PP.csv
#   inflating: MERGED2012_13_PP.csv
#   inflating: MERGED2013_14_PP.csv
#   inflating: MERGED2014_15_PP.csv
#   inflating: MERGED2015_16_PP.csv
#   inflating: MERGED2016_17_PP.csv
#   inflating: MERGED2017_18_PP.csv
#   inflating: MERGED2018_19_PP.csv
#   inflating: MERGED2019_20_PP.csv
#   inflating: MERGED2020_21_PP.csv
#   inflating: Most-Recent-Cohorts-Field-of-Study.csv
#   inflating: Most-Recent-Cohorts-Institution.csv

# %% [markdown]
# ## Step 3 - Import Libraries

# %%
#(Write code below)
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Step 4 - Display the current working directory using os.getcwd()
#
# You would need to import a standard Python library called os which stands for operating system. so place that import statement in the previous cell. Since your notebook and your data files may or may not in the same folder, you want to make sure what the current working folder is and how to access a data file in a different folder.

# %%
#(Write code below)
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ## Step 5 - Get the list of file names
#
# os library has a method call listdir which generates a list of files in a directory/folder. Use this method to assign the contents (list of file names) of the data folder to a variable and display it. If necessary, you can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

# %%
#(Write code below)
os.listdir()
# Out:
# ['.config',
#  'MERGED2006_07_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'Crosswalks.zip',
#  'MERGED2012_13_PP.csv',
#  'MERGED2019_20_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'Most-Recent-Cohorts-Field-of-Study.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'FieldOfStudyData1718_1819_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'FieldOfStudyData1617_1718_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'data.yaml',
#  'Most-Recent-Cohorts-Institution.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2020_21_PP.csv',
#  'CollegeScorecard_Raw_Data_09012022.zip',
#  'MERGED2001_02_PP.csv',
#  'sample_data']

# %% [markdown]
# ## Step 6 - Process only the yearly data files
#
# The folder contains files that are not the yearly data files. Write code to remove the unwanted files from the list variable.
#
# Note: don't remove/delete these files from the folder in the folder.
# For example, use the file extension to only use the csv files or use the name patter - data file name begins with "MERGED". You can use the concept of list comprehension to write just *one* line of code as well as using a for loop, your choice.

# %%
#(Write code below)
filelist= [f for f in os.listdir() if f.startswith("MERGED")]
filelist.sort()
filelist
# Out:
# ['MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'MERGED2019_20_PP.csv',
#  'MERGED2020_21_PP.csv']

# %% [markdown]
# ## Step 7 - Load data files
#
# Now that you have a clean list of the yearly files, you want to loop through them and read them into a dataframe one at a time. You only load six columns: ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
#
# You should use "usecols" option of Pandas to avoid reading unwanted columns. You also want to add a new column call "YEAR" to differentiate the data frames from each other. The YEAR variable should be yyyy format so tht you can convert them into integer. If you use the format yyyy-yy (such as 1997-98 school year), you will not be able to convert them directly to integer. If you use scatter plot, the YEAR needs to be converted to integer or float.
#
# You would use an empty list and append the yearly dataframes to the list. After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a new single data frame.
#
# Note: this exercise incorporates many techques we learned before:
#
# - list (creating an empty, append an item to the list)
# - for loop
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
#
# This exercise may appear challenging but it worths the effort. You will learn a lot and love it. I promise.

# %%
#(Write code here)
mergedlist = []

for filename in filelist:
    df = pd.read_csv(filename, usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"],index_col=None, header=0)
    df['YEAR'] = filename.split('.')[0].split('_')[0].split('D')[-1]
    mergedlist.append(df)

df_merged = pd.concat(mergedlist, axis=0, ignore_index=True)

# %% [markdown]
# ## Step 8 - Explore the new dataframe
#
# For example, # of observations, varibles, head, tail, sample, missing values, statistics, etc.

# %%
#(Write code here)
df_merged.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL     0.0       NaN
# 1  100654                Alabama A & M University     AL     5.0       NaN
# 2  100663     University of Alabama at Birmingham     AL     5.0       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0       NaN
# 4  100690                      Amridge University     AL     5.0       NaN
#
#    TUITIONFEE_IN  YEAR
# 0            NaN  1996
# 1            NaN  1996
# 2            NaN  1996
# 3            NaN  1996
# 4            NaN  1996

# %%
df_merged.tail()
# Out:
#           UNITID                                             INSTNM STABBR  \
# 176702  49576719  Pennsylvania State University-Penn State Wilke...     PA
# 176703  49576720      Pennsylvania State University-Penn State York     PA
# 176704  49576721  Pennsylvania State University-Penn State Great...     PA
# 176705  49576722  Pennsylvania State University-Penn State Harri...     PA
# 176706  49576723  Pennsylvania State University-Penn State Brand...     PA
#
#         REGION  ADM_RATE  TUITIONFEE_IN  YEAR
# 176702     2.0       NaN        13604.0  2020
# 176703     2.0       NaN        14486.0  2020
# 176704     2.0       NaN            NaN  2020
# 176705     2.0       NaN        15216.0  2020
# 176706     2.0       NaN        14486.0  2020

# %%
df_merged.sample(n=5)
# Out:
#         UNITID                                             INSTNM STABBR  \
# 20900   110051                                 Bethany University     CA
# 132052  437325  Linfield University-Online and Continuing Educ...     OR
# 72200   241304                 Columbia Central University-Caguas     PR
# 78025   210890                                Antonelli Institute     PA
# 100152  239017                                Lawrence University     WI
#
#         REGION  ADM_RATE  TUITIONFEE_IN  YEAR
# 20900      8.0       NaN            NaN  1999
# 132052     8.0       NaN            NaN  2014
# 72200      9.0       NaN         5685.0  2006
# 78025      2.0    0.8341        17250.0  2007
# 100152     3.0    0.6625        36312.0  2010

# %%
df_merged.describe()
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN
# count  1.767070e+05  176706.000000  48863.000000   86867.000000
# mean   1.054338e+06       4.559279      0.693785   12037.588290
# std    4.959072e+06       2.188341      0.217019   10462.970227
# min    1.006360e+05       0.000000      0.000000       0.000000
# 25%    1.641730e+05       3.000000      0.556700    3936.000000
# 50%    2.136310e+05       5.000000      0.719500    9422.000000
# 75%    4.137780e+05       6.000000      0.857100   16490.000000
# max    4.957672e+07       9.000000      1.000000   74787.000000

# %% [markdown]
# ## Step 9 - UMBC
#
# The dataframe contains many years of data of all U.S. colleges. let's just look at UMBC. Filter/query the dataframe to retrieve only rows that belong to UMBC (one row represent one year). Save the UMNC data to a new data frame. using a new variable for the UMBC data frame, so that the old big data frame is still available for later use.

# %%
#(Write code here)
df_umbc = df_merged.loc[df_merged['INSTNM'].str.contains("University of Maryland-Baltimore County")]
df_umbc
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 104960  163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 2151         NaN            NaN  1996
# 9056         NaN            NaN  1997
# 15923        NaN            NaN  1998
# 22598        NaN            NaN  1999
# 29178        NaN         5490.0  2000
# 35821     0.6551         5910.0  2001
# 42524     0.6327         6362.0  2002
# 49156     0.5757         7388.0  2003
# 55786     0.7014         8020.0  2004
# 62522     0.7143         8520.0  2005
# 69401     0.7153         8622.0  2006
# 76332     0.6895         8708.0  2007
# 83291     0.7174         8780.0  2008
# 90324     0.6890         8872.0  2009
# 97506     0.6589         9171.0  2010
# 104960    0.6081         9467.0  2011
# 112672    0.6035         9764.0  2012
# 120503    0.6315        10068.0  2013
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018
# 164723    0.6103        12028.0  2019
# 171401    0.6948         9420.0  2020

# %% [markdown]
# ## Step 10 - Explore the new dataframe
#
# For example, # of observations, varibles, head, tail, sample, missing values, statistics, etc

# %%
#(Write code here)
df_umbc.head()
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 9056   163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
# 22598  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  YEAR
# 2151        NaN            NaN  1996
# 9056        NaN            NaN  1997
# 15923       NaN            NaN  1998
# 22598       NaN            NaN  1999
# 29178       NaN         5490.0  2000

# %%
df_umbc.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018
# 164723    0.6103        12028.0  2019
# 171401    0.6948         9420.0  2020

# %%
df_umbc.sample(n = 5)
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 97506     0.6589         9171.0  2010
# 2151         NaN            NaN  1996
# 15923        NaN            NaN  1998
# 143685    0.5683        11264.0  2016
# 164723    0.6103        12028.0  2019

# %%
df_umbc.isna().sum()
# Out:
# UNITID           0
# INSTNM           0
# STABBR           0
# REGION           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# YEAR             0
# dtype: int64

# %%
df_umbc.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN
# count      25.0    25.0  20.000000      21.000000
# mean   163268.0     2.0   0.641880    9168.571429
# std         0.0     0.0   0.051853    1854.082079
# min    163268.0     2.0   0.568300    5490.000000
# 25%    163268.0     2.0   0.600600    8520.000000
# 50%    163268.0     2.0   0.632100    9171.000000
# 75%    163268.0     2.0   0.690825   10384.000000
# max    163268.0     2.0   0.717400   12028.000000

# %% [markdown]
# ## Step 11 - Plot UMBC's in-state tution overtime Bar Chart

# %%
#(Write code here)
fig = plt.figure(figsize = (20, 10))
 
# creating the bar plot
plt.bar(list(df_umbc.YEAR.unique()),df_umbc.TUITIONFEE_IN.values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee")
plt.title("Plot for Instate tution fee over years")
plt.show()

# %% [markdown]
# ## Step 12 - Plot UMBC's in-state tution overtime using line Chart

# %%
#(Write code here)
fig = plt.figure(figsize = (20, 10))
plt.plot(df_umbc.YEAR,df_umbc.TUITIONFEE_IN.values)
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee")
plt.title("Plot for Instate tution fee over years")
plt.show()

# %% [markdown]
# ## Step 13 - Tuition Growth Rate
#
# Now let's look at the tuition growth rate year over year. We need to calculate UMBC tuition change percentage each year. First convert the TUITIONFEE_IN column to a Python List

# %%
#(Write code here)
tutionfee = list(df_umbc['TUITIONFEE_IN'])

# %% [markdown]
# ## Step 14 - Loop through the list and calculate the % change each year over the prior year
#
# This takes some effort. Not hard, just some abstract/logical thinking and some experiments. Have fun on this one.

# %%
 #(Write code here)
tut_fee = []
tut_fee.append(np.nan)
for x, y in zip(tutionfee, tutionfee[1:]):
    tut_fee.append((y - x) / x * 100)

tut_fee
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.650273224043716,
#  7.648054145516074,
#  16.12700408676517,
#  8.554412560909583,
#  6.234413965087282,
#  1.1971830985915493,
#  0.9974483878450475,
#  0.8268259072117593,
#  1.0478359908883828,
#  3.370153291253381,
#  3.227565151019518,
#  3.1372134783986483,
#  3.11347808275297,
#  3.1386571315057608,
#  5.989984591679507,
#  2.344175904052335,
#  2.254971590909091,
#  2.2573363431151243,
#  2.122601460349805,
#  -21.68274027269704]

# %% [markdown]
# ## Step 15 - Round up the percentage to two decimal points
#
# The resulting number has many decimal points which are unnecessary and not visually appealing. You can use for loop. Or better, use list comprehension for simplicity/brevity.

# %%
#(Write code here)
Percent_list_tut = [round(item, 2) for item in tut_fee]
Percent_list_tut
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.65,
#  7.65,
#  16.13,
#  8.55,
#  6.23,
#  1.2,
#  1.0,
#  0.83,
#  1.05,
#  3.37,
#  3.23,
#  3.14,
#  3.11,
#  3.14,
#  5.99,
#  2.34,
#  2.25,
#  2.26,
#  2.12,
#  -21.68]

# %% [markdown]
# ## Step 16 - Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
#
# Not as hard as you may think. If you get stuck, you think too hard. Google it and you will find the answer.

# %%
#(Write code here)
df_umbc['PCT_CHANGE'] = Percent_list_tut
df_umbc.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         UNITID                                   INSTNM STABBR  REGION  \
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
# 164723  163268  University of Maryland-Baltimore County     MD     2.0
# 171401  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR  PCT_CHANGE
# 143685    0.5683        11264.0  2016        2.34
# 150891    0.6021        11518.0  2017        2.25
# 157940    0.5794        11778.0  2018        2.26
# 164723    0.6103        12028.0  2019        2.12
# 171401    0.6948         9420.0  2020      -21.68

# %% [markdown]
# ## Step 17 - Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

# %%
# (write code here)

fig = plt.figure(figsize = (20, 10))
 
# creating the bar plot
plt.bar(list(df_umbc.YEAR.unique()),df_umbc.PCT_CHANGE.values, color ='maroon',
        width = 0.4)
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee Percentage Chane")
plt.title("Plot for Instate tution fee  per centage chane over years")
plt.show()

# %%
#line plot
fig = plt.figure(figsize = (20, 10))
plt.plot(df_umbc.YEAR,df_umbc.PCT_CHANGE.values)
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee Percentage Chane")
plt.title("Plot for Instate tution fee  per centage chane over years")
plt.show()

# %% [markdown]
# ## Step 18 - Define Growth Rate Function
#
# Since we want to do the same calculation for JHU. Instead of doing it piecemeal as we did for UMBC. Let's create a function which can be reused for any college. This function takes a list of tuitions and return a list of percentage changes year over year. This function can be used later.

# %%
#(Write code here)
def percent_calc(intutionfee):
   percentage_change = []
   for j in range(len(intutionfee)):
     percentage_change_value=((intutionfee[j]-intutionfee[j-1])/intutionfee[j-1])*100
     percentage_change.append(percentage_change_value)
     Percent_list_JHU = [round(item, 2) for item in percentage_change]
   return Percent_list_JHU

# %% [markdown]
# ## Step 19 - Get JHU Data
#
# The dataframe contains many years of data of all U.S. colleges. Let's just look at JHU. Filter/query the dataframe to retrieve only rows that belong to JHU. Save the JHU data to a new data frame using a new variable so that the old big data frame is still available for later use.

# %%
#(Write code here)
df_JHU = df_merged[df_merged['INSTNM']== "Johns Hopkins University"]
df_JHU
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# 90317   162928  Johns Hopkins University     MD     2.0    0.2782
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 104953  162928  Johns Hopkins University     MD     2.0    0.1940
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
# 164718  162928  Johns Hopkins University     MD     2.0    0.1117
# 171396  162928  Johns Hopkins University     MD     2.0    0.1106
#
#         TUITIONFEE_IN  YEAR
# 2139              NaN  1996
# 9046              NaN  1997
# 15914             NaN  1998
# 22589             NaN  1999
# 29169         24930.0  2000
# 35812         26210.0  2001
# 42515         27390.0  2002
# 49148         28730.0  2003
# 55779         30140.0  2004
# 62515         31620.0  2005
# 69394         33900.0  2006
# 76325         35900.0  2007
# 83284         37700.0  2008
# 90317         39150.0  2009
# 97499         40680.0  2010
# 104953        42280.0  2011
# 112665        43390.0  2012
# 120496        45470.0  2013
# 128346        47060.0  2014
# 136057        48710.0  2015
# 143678        50410.0  2016
# 150886        52170.0  2017
# 157935        53740.0  2018
# 164718        55350.0  2019
# 171396        54160.0  2020

# %% [markdown]
# ## Step 20 - Plot JHU's in-state tuition overtime
#
# Let's plot bar and then line chart.

# %%
# <14> 
# Plot JHU's in-state tuition overtime from 1996 to 2019. 
# Let's plot bar and line chart together

#(Write code here)
fig = go.Figure()

JHU_tutionfee = go.Bar(
    x=df_JHU["YEAR"],
    y=df_JHU["TUITIONFEE_IN"], 
)

fig.add_trace(JHU_tutionfee)

fig.update_layout(
    title = "John Hopkin's tutionfee over years",
    xaxis = {"title":"Years"},
    yaxis = {"title":"In_Tutionfee"}
)


JHU_tutionfee = go.Line(
    x=df_JHU["YEAR"],
    y=df_JHU["TUITIONFEE_IN"], 
)

fig.add_trace(JHU_tutionfee)

fig.update_layout(
    title = "John Hopkin's tutionfee over years",
    xaxis = {"title":"Years"},
    yaxis = {"title":"In_Tutionfee"}
)

fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bfb16985-5c7d-4507-be30-daf59ac1ec1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfb16985-5c7d-4507-be30-daf59ac1ec1f")) {                    Plotly.newPlot(                        "bfb16985-5c7d-4507-be30-daf59ac1ec1f",                        [{"x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"y":[null,null,null,null,24930.0,26210.0,27390.0,28730.0,30140.0,31620.0,33900.0,35900.0,37700.0,39150.0,40680.0,42280.0,43390.0,45470.0,47060.0,48710.0,50410.0,52170.0,53740.0,55350.0,54160.0],"type":"bar"},{"x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"y":[null,null,null,null,24930.0,26210.0,27390.0,28730.0,30140.0,31620.0,33900.0,35900.0,37700.0,39150.0,40680.0,42280.0,43390.0,45470.0,47060.0,48710.0,50410.0,52170.0,53740.0,55350.0,54160.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666 ...

# %% [markdown]
# ## Step 21 - Calculate Tuition Growth Rate using the Function defined earlier

# %%
# Write code here
percentage_change_JHU = percent_calc(df_JHU['TUITIONFEE_IN'].tolist())
percentage_change_JHU
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  5.13,
#  4.5,
#  4.89,
#  4.91,
#  4.91,
#  7.21,
#  5.9,
#  5.01,
#  3.85,
#  3.91,
#  3.93,
#  2.63,
#  4.79,
#  3.5,
#  3.51,
#  3.49,
#  3.49,
#  3.01,
#  3.0,
#  -2.15]

# %% [markdown]
# ## Step 22 - Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

# %%
#(Write code here)
df_JHU['PCT_CHANGE'] = percentage_change_JHU
df_JHU
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# 90317   162928  Johns Hopkins University     MD     2.0    0.2782
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 104953  162928  Johns Hopkins University     MD     2.0    0.1940
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
# 164718  162928  Johns Hopkins University     MD     2.0    0.1117
# 171396  162928  Johns Hopkins University     MD     2.0    0.1106
#
#         TUITIONFEE_IN  YEAR  PCT_CHANGE
# 2139              NaN  1996         NaN
# 9046              NaN  1997         NaN
# 15914             NaN  1998         NaN
# 22589             NaN  1999         NaN
# 29169         24930.0  2000         NaN
# 35812         26210.0  2001        5.13
# 42515         27390.0  2002        4.50
# 49148         28730.0  2003        4.89
# 55779         30140.0  2004        4.91
# 62515         31620.0  2005        4.91
# 69394         33900.0  2006        7.21
# 76325         35900.0  2007        5.90
# 83284         37700.0  2008        5.01
# 90317         39150.0  2009        3.85
# 97499         40680.0  2010        3.91
# 104953        42280.0  2011        3.93
# 112665        43390.0  2012        2.63
# 120496        45470.0  2013        4.79
# 128346        47060.0  2014        3.50
# 136057        48710.0  2015        3.51
# 143678        50410.0  2016        3.49
# 150886        52170.0  2017        3.49
# 157935        53740.0  2018        3.01
# 164718        55350.0  2019        3.00
# 171396        54160.0  2020       -2.15

# %% [markdown]
# ## Step 23 - Plot the JHU percentage changes tuitions over time
#
# Bar plot first, then line plot.

# %%
#(Write code here)
fig = plt.figure(figsize = (20, 10))
 
# creating the bar plot
plt.bar(list(df_JHU["YEAR"].unique()),df_JHU["PCT_CHANGE"].values, color ='maroon',
        width = 0.4)
plt.plot(df_JHU.YEAR,df_JHU.PCT_CHANGE.values)
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee Percentage Chane")
plt.title("Plot for Instate tution fee  per centage chane over years")
plt.show()

# %% [markdown]
# ## Step 24 - Compare UMBC and JHU
#
# In order to plot both UMBC and JHU tuition change over time in the same plot, we need to combine the two datasets using the common key of YEAR.
#
# First make a umbc2 dataframe with only two columns needed. We don't need other columns. Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge. This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE", we rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully, Feel free to try it without changing the column names.

# %%
#(Write code here)
UMBC_data = df_umbc[['YEAR', 'PCT_CHANGE']]
JHU_data = df_JHU[['YEAR', 'PCT_CHANGE']]

# %% [markdown]
# ## Step 25
#
# Then make a jhu2 dataframe with only two columns needed. WE don't need other columns. Also change the column name from "PCT_CHANGE" to "JHU_PCT"  in preparation for the merge

# %%
#(Write code here)
UMBC_data = UMBC_data.rename(columns={'PCT_CHANGE': 'UMBC_PCT'})
JHU_data = JHU_data.rename(columns={'PCT_CHANGE': 'JHU_PCT'})

# %% [markdown]
# ## Step 26 - Merger the two data frames and display the new dataframe

# %%
#(Write code here)
UMBC_JHU = pd.merge(UMBC_data, JHU_data, on="YEAR")
UMBC_JHU
# Out:
#     YEAR  UMBC_PCT  JHU_PCT
# 0   1996       NaN      NaN
# 1   1997       NaN      NaN
# 2   1998       NaN      NaN
# 3   1999       NaN      NaN
# 4   2000       NaN      NaN
# 5   2001      7.65     5.13
# 6   2002      7.65     4.50
# 7   2003     16.13     4.89
# 8   2004      8.55     4.91
# 9   2005      6.23     4.91
# 10  2006      1.20     7.21
# 11  2007      1.00     5.90
# 12  2008      0.83     5.01
# 13  2009      1.05     3.85
# 14  2010      3.37     3.91
# 15  2011      3.23     3.93
# 16  2012      3.14     2.63
# 17  2013      3.11     4.79
# 18  2014      3.14     3.50
# 19  2015      5.99     3.51
# 20  2016      2.34     3.49
# 21  2017      2.25     3.49
# 22  2018      2.26     3.01
# 23  2019      2.12     3.00
# 24  2020    -21.68    -2.15

# %% [markdown]
# ## Step 27 - Plot UMBC and JHU separately on the same line plot

# %%
#(Write code here)
fig = go.Figure()

Merged_UMBC = go.Line(
    x=UMBC_JHU["YEAR"],
    y=UMBC_JHU["UMBC_PCT"],
    name="UMBC"
)

Merged_JHU = go.Line(
    x=UMBC_JHU["YEAR"],
    y=UMBC_JHU["JHU_PCT"],
    name="JHU"
    
)

fig.add_trace(Merged_UMBC)
fig.add_trace(Merged_JHU)

fig.update_layout(
    title="UMBC vs JHU tution fee Growth",
    xaxis={"title":"Year"},
    yaxis={"title":"Percentage Change"}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="44561fbe-9629-4e0e-91e9-b469c295d4a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44561fbe-9629-4e0e-91e9-b469c295d4a1")) {                    Plotly.newPlot(                        "44561fbe-9629-4e0e-91e9-b469c295d4a1",                        [{"name":"UMBC","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"y":[null,null,null,null,null,7.65,7.65,16.13,8.55,6.23,1.2,1.0,0.83,1.05,3.37,3.23,3.14,3.11,3.14,5.99,2.34,2.25,2.26,2.12,-21.68],"type":"scatter"},{"name":"JHU","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"y":[null,null,null,null,null,5.13,4.5,4.89,4.91,4.91,7.21,5.9,5.01,3.85,3.91,3.93,2.63,4.79,3.5,3.51,3.49,3.49,3.01,3.0,-2.15],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]], ...

# %%
UMBC_JHU.plot.bar(x = 'YEAR', y = ['UMBC_PCT', 'JHU_PCT'], figsize = (15, 15))
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee Percentage Chane")
plt.title("Plot for Instate tution fee  per centage chane over years for UMBC and JHU")
plt.show()

# %%
fig = plt.figure(figsize = (20, 10))
plt.plot(UMBC_JHU.YEAR,UMBC_JHU[['UMBC_PCT', 'JHU_PCT']].values)
plt.xlabel("Years")
plt.ylabel("Instate Tution Fee Percentage Chane")
plt.title("Plot for Instate tution fee  per centage chane over years for UMBC and JHU")
plt.show()

# %% [markdown]
# ## Step 28 - Document your observation of the comparison plots using the following Markdown cell

# %% [markdown]
# #### Based on my observation of the plots
# #### blah, blah
# #### blah, blah
# #### ...
# #### blah, blah

# %%
# The end.
