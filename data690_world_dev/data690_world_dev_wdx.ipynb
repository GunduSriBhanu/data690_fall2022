# %% [markdown]
# <a href="https://colab.research.google.com/github/GunduSriBhanu/data690_fall2022/blob/main/data690_world_dev/data690_world_dev_wdx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='##B8860B'> DATA 690 INDIVIDUAL PROJECT PART B </font>

# %% [markdown]
# # Importance of education and Unemployment in G20 Countries
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
#       The data analyses the G20 countries providing importane to education from the years 2010 to 2015. It even analyses the employment and education proportionality.
#
#
# Importing libraries for Data loading, Data analysis and Data Visualization.

# %%
#importing libraries
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Data Loading
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
#     The data is loaded from the dataset provided in "https://www.worlddev.xyz/" with indicators with Health, Education and Economy.

# %% [markdown]
# ### Reading data from the github path and storing in the data frame df

# %%
# Load the dataset from github link
df =  pd.read_csv("https://raw.githubusercontent.com/GunduSriBhanu/data690_fall2022/main/data690_world_dev/data/Education_wdx_data_2010_2015.csv")

# Shape of the data with rows and columns
df.shape
# Out:
# (630, 9)

# %% [markdown]
# ### Printing top 5 rows of dataframe

# %%
df.head()
# Out:
#    Unnamed: 0  Year  value       indicator Country Code Country Name  \
# 0           0  2010   7.71  SL.UEM.TOTL.ZS          ARG    Argentina
# 1           1  2011   7.18  SL.UEM.TOTL.ZS          ARG    Argentina
# 2           2  2012   7.22  SL.UEM.TOTL.ZS          ARG    Argentina
# 3           3  2013   7.10  SL.UEM.TOTL.ZS          ARG    Argentina
# 4           4  2014   7.27  SL.UEM.TOTL.ZS          ARG    Argentina
#
#                        Region         Income Group Lending Type
# 0  Latin America & Caribbean   Upper middle income         IBRD
# 1  Latin America & Caribbean   Upper middle income         IBRD
# 2  Latin America & Caribbean   Upper middle income         IBRD
# 3  Latin America & Caribbean   Upper middle income         IBRD
# 4  Latin America & Caribbean   Upper middle income         IBRD

# %% [markdown]
# ### Printing bottom 5 rows of dataframe

# %%
df.tail()
# Out:
#      Unnamed: 0  Year         value       indicator Country Code  \
# 625         625  2011  8.029500e+11  NY.ADJ.AEDU.CD          USA
# 626         626  2012  7.518343e+11  NY.ADJ.AEDU.CD          USA
# 627         627  2013  7.575437e+11  NY.ADJ.AEDU.CD          USA
# 628         628  2014  7.913655e+11  NY.ADJ.AEDU.CD          USA
# 629         629  2015  8.221408e+11  NY.ADJ.AEDU.CD          USA
#
#       Country Name         Region Income Group    Lending Type
# 625  United States  North America  High income  Not classified
# 626  United States  North America  High income  Not classified
# 627  United States  North America  High income  Not classified
# 628  United States  North America  High income  Not classified
# 629  United States  North America  High income  Not classified

# %% [markdown]
# ### Printinf random 5 rows in a dataset

# %%
df.sample(5)
# Out:
#      Unnamed: 0  Year         value       indicator Country Code  \
# 566         566  2012  2.720600e+10  NY.ADJ.AEDU.CD          IDN
# 359         359  2013  5.042889e+07     SP.POP.TOTL          KOR
# 93           93  2013  2.456000e+01  SL.UEM.TOTL.ZS          ZAF
# 344         344  2010  5.927742e+07     SP.POP.TOTL          ITA
# 79           79  2011  6.540000e+00  SL.UEM.TOTL.ZS          RUS
#
#            Country Name                 Region         Income Group  \
# 566           Indonesia    East Asia & Pacific  Lower middle income
# 359         Korea, Rep.    East Asia & Pacific          High income
# 93         South Africa    Sub-Saharan Africa   Upper middle income
# 344               Italy  Europe & Central Asia          High income
# 79   Russian Federation  Europe & Central Asia  Upper middle income
#
#        Lending Type
# 566            IBRD
# 359  Not classified
# 93             IBRD
# 344  Not classified
# 79             IBRD

# %% [markdown]
# ### Analysing the null values and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    630 non-null    int64
#  1   Year          630 non-null    int64
#  2   value         630 non-null    float64
#  3   indicator     630 non-null    object
#  4   Country Code  630 non-null    object
#  5   Country Name  630 non-null    object
#  6   Region        630 non-null    object
#  7   Income Group  630 non-null    object
#  8   Lending Type  630 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 44.4+ KB

# %% [markdown]
# ### Checking for the existance of null values in the dataset

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Year            0
# value           0
# indicator       0
# Country Code    0
# Country Name    0
# Region          0
# Income Group    0
# Lending Type    0
# dtype: int64

# %% [markdown]
# ## Data Cleaning:
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# Dropping unnecessary columns

# %%
df= df.drop(columns=["Lending Type","Unnamed: 0"])
df.columns
# Out:
# Index(['Year', 'value', 'indicator', 'Country Code', 'Country Name', 'Region',
#        'Income Group'],
#       dtype='object')

# %% [markdown]
# ### Checking the indicators for health, wealth and economy

# %%
df.indicator.unique()
# Out:
# array(['SL.UEM.TOTL.ZS', 'SE.SEC.CUAT.PO.ZS', 'NY.ADJ.AEDU.GN.ZS',
#        'SE.TER.CUAT.MS.ZS', 'SP.POP.TOTL', 'SE.TER.CUAT.DO.ZS',
#        'SP.POP.AG25.TO.UN', 'NY.ADJ.AEDU.CD'], dtype=object)

# %% [markdown]
# ### Checking all the G20 country names

# %%
df['Country Name'].unique()
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Korea, Rep.',
#        'Mexico', 'Russian Federation', 'Saudi Arabia', 'South Africa',
#        'Turkiye', 'United Kingdom', 'United States'], dtype=object)

# %% [markdown]
# ### Time Series: Analysing data and converting Year column to datetime data type

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y').dt.year
df.sample(5)
# Out:
#      Year         value          indicator Country Code        Country Name  \
# 167  2010  5.000000e+00  NY.ADJ.AEDU.GN.ZS          CAN              Canada
# 301  2015  2.381600e+07        SP.POP.TOTL          AUS           Australia
# 370  2012  1.432017e+08        SP.POP.TOTL          RUS  Russian Federation
# 536  2012  8.874000e+10     NY.ADJ.AEDU.CD          CAN              Canada
# 59   2015  1.190000e+01     SL.UEM.TOTL.ZS          ITA               Italy
#
#                     Region         Income Group
# 167          North America          High income
# 301    East Asia & Pacific          High income
# 370  Europe & Central Asia  Upper middle income
# 536          North America          High income
# 59   Europe & Central Asia          High income

# %%
# Data info after transformations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          630 non-null    int64
#  1   value         630 non-null    float64
#  2   indicator     630 non-null    object
#  3   Country Code  630 non-null    object
#  4   Country Name  630 non-null    object
#  5   Region        630 non-null    object
#  6   Income Group  630 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 34.6+ KB

# %% [markdown]
# ### Summary of statistics

# %%
df.describe()
# Out:
#               Year         value
# count   630.000000  6.300000e+02
# mean   2012.530159  2.216642e+10
# std       1.734769  8.367750e+10
# min    2010.000000  3.213000e-02
# 25%    2011.000000  5.211582e+00
# 50%    2013.000000  3.028515e+05
# 75%    2014.000000  1.199731e+08
# max    2015.000000  8.221408e+11

# %% [markdown]
# ## Data Visualization
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### Analysing the data for the year 2013
#
# For the year 2013, analysing the population for top 10 countries with highest population with bar graph. Among these China, India and United states are the highest populated coutries.

# %%
df2 = df.query("indicator == 'SP.POP.TOTL' and Year == 2013") 
# Bar Plotly chart for top 10 populated countries
fig = px.bar(
    df2.sort_values(by="value", ascending=False)[0:10], 
    x="Country Name",
    y = "value", 
    title = "2013 Population of G20 Countries", 
    color = "Country Name", 
    template="plotly_dark"
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Further analysing the data with population for G20 countries whose age is more than 25 years.

# %%
#bar plot for top 10 populated countries with age 25+
fig = px.bar(
    df.query("indicator == 'SP.POP.AG25.TO.UN' and Year == 2013").sort_values(by="value", ascending=False)[0:10], 
    x="Country Name",
    y = "value", 
    title = "25+ Population of G20 Countries in 2013", 
    color = "Country Name", 
    template="plotly_dark"
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Among these, China and India population are almost equal with population of more than 25 years of age followed by Unites States.

# %% [markdown]
# ## Countries with highest education
#
# Among these contries analysing the population with completed secondary, masters and doctorates degrees in the G20 Countries in the year 2013.

# %%
# pie plotly chart for education category in year 2013
fig = px.pie(
    df.query("indicator == 'SE.SEC.CUAT.PO.ZS' and Year == 2013"),  
    names="Country Name",
    values = "value", 
    title = "2013 population with secondary education", 
    color = "Country Name", 
    template="plotly_dark"
)
fig.update_traces(textposition='inside', textinfo='label+percent+value')
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the secondary education data, Australia and Germany has highest secondary education completed population for the year 2013.

# %%
# pie plotly chart for education category in year 2013
fig = px.pie(
    df.query("indicator == 'SE.TER.CUAT.MS.ZS' and Year == 2013"),  
    names="Country Name",
    values = "value", 
    title = "2013 population with masters education", 
    color = "Country Name", 
    template="plotly_dark"
)
fig.update_traces(textposition='inside', textinfo='label+percent+value')
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  From the analysis, masters education completed is highest in United States, United Kingdom followed by Australia.

# %%
# pie plotly chart for education category in year 2013
fig = px.pie(
    df.query("indicator == 'SE.TER.CUAT.DO.ZS' and Year == 2013"),  
    names="Country Name",
    values = "value", 
    title = "2013 population with Doctorates", 
    color = "Country Name", 
    template="plotly_dark"
)
fig.update_traces(textposition='inside', textinfo='label+percent+value')
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **From the analysis**, the doctorates are highest for United States and United Kingdom.

# %% [markdown]
# ## From my analysis of education,
# * **United states** had the population with highest education of masters and Doctorates.
# * **United Kingdom** has highest Masters and Doctorates after United States.
# * Overall **United States, United Kingdom and Australia** are providing highest education and encouraging education.

# %% [markdown]
# ## Analysis based on Regions

# %%
# Analysis based on regions with mean aggregate
df_unemp = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_unemp = df_unemp[["Year", "value","Region"]]
df_unemp = df_unemp.groupby(['Year','Region']).agg(["mean"])
df_unemp.columns = ['_'.join(col) for col in df_unemp.columns.values]
df_unemp.reset_index(inplace=True)
df_unemp[0:5]
# Out:
#    Year                      Region  value_mean
# 0  2010         East Asia & Pacific    4.754000
# 1  2010       Europe & Central Asia    8.336667
# 2  2010  Latin America & Caribbean     6.761333
# 3  2010  Middle East & North Africa    5.550000
# 4  2010               North America    8.845000

# %%
# Bar plot with mean aggregate
fig = px.bar(
    df_unemp.query('Year == 2013').sort_values(by="value_mean", ascending=False),  
    x = "Region",
    y = "value_mean", 
    title = "2013 Regions of unemployment", 
    color = "Region",
    template="plotly_dark"
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### From my observation,
# **Sub-Saharan Africa** region has highest unemployment in the year 2013

# %% [markdown]
# ### Comparison of unemployment with expenditure on education

# %%
# Filtering data of unemployment and expenditure indicators
my_indicators = ["SL.UEM.TOTL.ZS", "NY.ADJ.AEDU.GN.ZS"]

df_unemp_expend = df[df["indicator"].isin(my_indicators)]
df_unemp_expend.shape
# Out:
# (228, 7)

# %%
# Data with the selected columns
df_unemp_expend = df_unemp_expend[["Year",	"value",	"indicator",	"Country Code",	"Country Name"]]
df_unemp_expend
# Out:
#      Year     value          indicator Country Code   Country Name
# 0    2010  7.710000     SL.UEM.TOTL.ZS          ARG      Argentina
# 1    2011  7.180000     SL.UEM.TOTL.ZS          ARG      Argentina
# 2    2012  7.220000     SL.UEM.TOTL.ZS          ARG      Argentina
# 3    2013  7.100000     SL.UEM.TOTL.ZS          ARG      Argentina
# 4    2014  7.270000     SL.UEM.TOTL.ZS          ARG      Argentina
# ..    ...       ...                ...          ...            ...
# 258  2011  5.050000  NY.ADJ.AEDU.GN.ZS          USA  United States
# 259  2012  4.502002  NY.ADJ.AEDU.GN.ZS          USA  United States
# 260  2013  4.404324  NY.ADJ.AEDU.GN.ZS          USA  United States
# 261  2014  4.396475  NY.ADJ.AEDU.GN.ZS          USA  United States
# 262  2015  4.396475  NY.ADJ.AEDU.GN.ZS          USA  United States
#
# [228 rows x 5 columns]

# %%
# pivot table for the indicators of unemployment and expenditure
df_eem_exp = pd.pivot_table(df_unemp_expend, values= 'value', index=['Country Code',	'Country Name', 'Year'], columns = 'indicator').reset_index()
df_eem_exp.head()
# Out:
# indicator Country Code Country Name  Year  NY.ADJ.AEDU.GN.ZS  SL.UEM.TOTL.ZS
# 0                  ARG    Argentina  2010           4.520000            7.71
# 1                  ARG    Argentina  2011           4.868164            7.18
# 2                  ARG    Argentina  2012           5.216329            7.22
# 3                  ARG    Argentina  2013           5.241807            7.10
# 4                  ARG    Argentina  2014           5.094118            7.27

# %%
# Scatter plotly chart for unemployment variation with expenditure in year 2013
fig = px.scatter(
    df_eem_exp.query("Year == 2013"), 
    x= "NY.ADJ.AEDU.GN.ZS",
    y = "SL.UEM.TOTL.ZS", 
    title = "Unemployment vs Expenditure on Education", 
    color="Country Name",
    template = 'plotly_dark'
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### From the observation,
# - **Korea and Japan** with ***lowest*** unemployment rate with medium contribution on education.
#
# - **South Africa** with ***highest*** unemployment rate eventhough the expenditure on education is highes t for South Africa.

# %% [markdown]
# ## From all these G20 countries observations,
# population is highest for countries China, India for 25+ years population and most of the degree earned are highest in United States, Canada, Australia, and Germany. The countries spending more on education with less unemployment is United states and Canada.China is lowest in expenditure for education and unemployment. Hence, will further analyses comparing these contries.

# %%
#filtering only selected countries
my_countries = ["USA","IND", "CHN", "AUS", "GBR"]

df_sc = df[df["Country Code"].isin(my_countries)]
df_sc.shape
# Out:
# (171, 7)

# %%
# Top 5 rows of dataframe 
df_sc.head()
# Out:
#     Year  value       indicator Country Code Country Name  \
# 6   2010   5.21  SL.UEM.TOTL.ZS          AUS    Australia
# 7   2011   5.08  SL.UEM.TOTL.ZS          AUS    Australia
# 8   2012   5.22  SL.UEM.TOTL.ZS          AUS    Australia
# 9   2013   5.66  SL.UEM.TOTL.ZS          AUS    Australia
# 10  2014   6.08  SL.UEM.TOTL.ZS          AUS    Australia
#
#                  Region Income Group
# 6   East Asia & Pacific  High income
# 7   East Asia & Pacific  High income
# 8   East Asia & Pacific  High income
# 9   East Asia & Pacific  High income
# 10  East Asia & Pacific  High income

# %%
# Bottom 5 rows of dataframe 
df_sc.tail()
# Out:
#      Year         value       indicator Country Code   Country Name  \
# 625  2011  8.029500e+11  NY.ADJ.AEDU.CD          USA  United States
# 626  2012  7.518343e+11  NY.ADJ.AEDU.CD          USA  United States
# 627  2013  7.575437e+11  NY.ADJ.AEDU.CD          USA  United States
# 628  2014  7.913655e+11  NY.ADJ.AEDU.CD          USA  United States
# 629  2015  8.221408e+11  NY.ADJ.AEDU.CD          USA  United States
#
#             Region Income Group
# 625  North America  High income
# 626  North America  High income
# 627  North America  High income
# 628  North America  High income
# 629  North America  High income

# %%
# sample rows of dataframe 
df_sc.sample(5)
# Out:
#      Year         value          indicator Country Code   Country Name  \
# 10   2014  6.080000e+00     SL.UEM.TOTL.ZS          AUS      Australia
# 513  2012  4.590244e+06  SP.POP.AG25.TO.UN          USA  United States
# 117  2013  4.164120e+01  SE.SEC.CUAT.PO.ZS          AUS      Australia
# 262  2015  4.396475e+00  NY.ADJ.AEDU.GN.ZS          USA  United States
# 112  2014  6.170000e+00     SL.UEM.TOTL.ZS          USA  United States
#
#                   Region Income Group
# 10   East Asia & Pacific  High income
# 513        North America  High income
# 117  East Asia & Pacific  High income
# 262        North America  High income
# 112        North America  High income

# %%
# Bottom 5 rows of dataframe
df_2013 = df_sc.query("Year == 2013")
df_2013['Country Code'].unique()
# Out:
# array(['AUS', 'CHN', 'IND', 'GBR', 'USA'], dtype=object)

# %% [markdown]
# ### Expenditure of Education over years for the countries Australia, China, India, United States, and United Kingdom.

# %%
# Comparison with aggregate mean
df_10_15 = df_sc.query("indicator == 'NY.ADJ.AEDU.GN.ZS'")
df_10_15 = df_10_15[["Year", "value",'Country Code']]
df_10_15 = df_10_15.groupby(['Year','Country Code']).agg(["mean"])
df_10_15.columns = ['_'.join(col) for col in df_10_15.columns.values]
df_10_15.reset_index(inplace=True)
df_10_15[0:5]
# Out:
#    Year Country Code  value_mean
# 0  2010          AUS    5.080000
# 1  2010          CHN    1.790000
# 2  2010          GBR    5.500000
# 3  2010          IND    3.080000
# 4  2010          USA    4.840966

# %%
# Comparison of line chart for all the years 
fig = px.line(
    df_10_15, 
    x="Year",
    y = "value_mean", 
    title = "expenditure on education over Years", 
    color='Country Code',
    template = 'plotly_dark'
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Unemployment over years for the countries Australia, China, India, United States, and United Kingdom.

# %%
# Unemployment comparison over years with aggregate mean
df_10_15_unemp = df_sc.query("indicator == 'SL.UEM.TOTL.ZS'")
df_10_15_unemp = df_10_15_unemp[["Year", "value",'Country Code']]
df_10_15_unemp = df_10_15_unemp.groupby(['Year','Country Code']).agg(["mean"])
df_10_15_unemp.columns = ['_'.join(col) for col in df_10_15_unemp.columns.values]
df_10_15_unemp.reset_index(inplace=True)
df_10_15_unemp
# Out:
#     Year Country Code  value_mean
# 0   2010          AUS       5.210
# 1   2010          CHN       4.530
# 2   2010          GBR       7.790
# 3   2010          IND       5.546
# 4   2010          USA       9.630
# 5   2011          AUS       5.080
# 6   2011          CHN       4.550
# 7   2011          GBR       8.040
# 8   2011          IND       5.426
# 9   2011          USA       8.950
# 10  2012          AUS       5.220
# 11  2012          CHN       4.570
# 12  2012          GBR       7.880
# 13  2012          IND       5.414
# 14  2012          USA       8.070
# 15  2013          AUS       5.660
# 16  2013          CHN       4.590
# 17  2013          GBR       7.520
# 18  2013          IND       5.424
# 19  2013          USA       7.370
# 20  2014          AUS       6.080
# 21  2014          CHN       4.610
# 22  2014          GBR       6.110
# 23  2014          IND       5.436
# 24  2014          USA       6.170
# 25  2015          AUS       6.050
# ...

# %%
# Comparison of line chart for all the years 2010-2015
fig = px.line(
    df_10_15_unemp, 
    x="Year",
    y = "value_mean", 
    title = "Unemployment over Years", 
    color='Country Code',
    template = 'plotly_dark'
)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## From the observations,
# - Australia is providing more importance to the education, and the expenditure on education is highest from 2012 comapred to USA.
#
# - Unemployment decreased in USA and UK is highest in the year 2015, compared to Australia and other countries.
#
# - From all these observations, even though the population of India and China is highest, the funds provided to these countries are lower and maintained almost constant unemployment.
#
# - USA, UK and Australia are developing in terms of education and employment.
#
# - Development of employment in United Kingdom and United States is almost same after 2013.

# %% [markdown]
# ## Conclusion
#
# ***United States, Australia and United Kingdom*** encouraged education by spending more on education irrespective of population. ***China and India*** with **highest population** provided less funds for education with less **unemployment rate** in comparison to India. China, even though highest populated country with lowest expenditure on education but with highest employment rate and with constant rate from years **2010 to 2015**.
# Overall, developed countries of G20 depends upon their education and employment.
